# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from IPython.display import Math
import openpyxl
import itertools
from decimal import Decimal,ROUND_HALF_UP
from sklearn.metrics import r2_score
from scipy.optimize import curve_fit

# %%
def tendline_all(df):

    #近似曲線(多項式近似)
    #次数は任意に変更可能
    fit=np.polyfit(df.iloc[:,0],df.iloc[:,1],2)
    data_x=df.iloc[:,0]
    data_y=np.poly1d(fit)(data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y,color="red")"""

    print(np.poly1d(fit))
    print(r2_score(df.iloc[:,1],data_y))

    #近似曲線(y=a*exp(x))
    def tendline1(x,a):
        return a*np.exp(x)

    popt1,cov1=curve_fit(tendline1,df.iloc[:,0],df.iloc[:,1])
    data_x=df.iloc[:,0]
    data_y1=popt1[0]*np.exp(data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y1,color="red")"""

    display(Math(r"y=ae^x"))
    print(popt1)
    print(r2_score(df.iloc[:,1],data_y1))

    #近似曲線(y=a**x)
    def tendline2(x,a):
        return a**x

    popt2,cov2=curve_fit(tendline2,df.iloc[:,0],df.iloc[:,1])
    data_x=df.iloc[:,0]
    data_y2=popt2[0]**(data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y2,color="red")"""

    display(Math(r"y=a^x"))
    print(popt2)
    print(r2_score(df.iloc[:,1],data_y2))

    #近似曲線(y=exp(ax))
    def tendline3(x,a):
        return np.exp(a*x)

    popt3,cov3=curve_fit(tendline3,df.iloc[:,0],df.iloc[:,1])
    data_x=df.iloc[:,0]
    data_y3=np.exp(popt3[0]*data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y3,color="red")"""

    display(Math(r"y=ae^x"))
    print(popt3)
    print(r2_score(df.iloc[:,1],data_y3))

    #近似曲線(y=a^(1/x))
    def tendline4(x,a):
        return a**(1/x)

    popt4,cov4=curve_fit(tendline4,df.iloc[:,0],df.iloc[:,1])
    data_x=df.iloc[:,0]
    data_y4=popt4[0]**(1/data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y4,color="red")"""

    display(Math(r"y=a^{\frac{1}{x}}"))
    print(popt4)
    print(r2_score(df.iloc[:,1],data_y4))

    #近似曲線(y=(1/x^)a)
    def tendline5(x,a):
        return (1/x)**a

    popt5,cov5=curve_fit(tendline5,df.iloc[:,0],df.iloc[:,1])
    data_x=df.iloc[:,0]
    data_y5=(1/data_x)**popt5[0]

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y5,color="red")
    """
    display(Math(r"y=(\frac{1}{x})^{a}"))
    print(popt5)
    print(r2_score(df.iloc[:,1],data_y5))

    #近似曲線(y=a/x)
    def tendline6(x,a):
        return (a/x)

    popt6,cov6=curve_fit(tendline6,df.iloc[:,0],df.iloc[:,1])
    data_x=df.iloc[:,0]
    data_y6=(popt6[0]/(data_x))

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y6,color="red")"""

    display(Math(r"y=\frac{a}{x}"))
    print(popt6)
    print(r2_score(df.iloc[:,1],data_y6))

    #近似曲線(y=a+b*log(x))
    def tendline7(x,a,b):
        return a+b*np.log(x)

    popt7,cov7=curve_fit(tendline7,df.iloc[:,0],df.iloc[:,1],maxfev=10000)
    data_x=df.iloc[:,0]
    data_y7=popt7[0]+popt7[1]*np.log(data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y7,color="red")"""

    display(Math(r"y=a+blog(x)"))
    print(popt7)
    print(r2_score(df.iloc[:,1],data_y7))

    #近似曲線(y=a^(1/x)+b/x)
    def tendline8(x,a,b):
        return a**(1/x)+b/x

    popt8,cov8=curve_fit(tendline8,df.iloc[:,0],df.iloc[:,1],maxfev=10000)
    data_x=df.iloc[:,0]
    data_y8=popt8[0]**(1/data_x)+(popt8[1]/data_x)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y8,color="red")"""

    display(Math(r"y=a^{\frac{1}{x}}+\frac{b}{x}"))
    print(popt8)
    print(r2_score(df.iloc[:,1],data_y8))

    #近似曲線(y=a/sin(x))
    def tendline9(x,a):
        return a/np.sin(np.pi*x/180)

    popt9,cov9=curve_fit(tendline9,df.iloc[:,0],df.iloc[:,1],maxfev=10000)
    data_x=df.iloc[:,0]
    data_y9=popt9[0]/np.sin(np.pi*data_x/180)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y9,color="red")"""

    display(Math(r"y=\frac{a}{sin(x)}"))
    print(popt9)
    print(r2_score(df.iloc[:,1],data_y9))

    #近似曲線(y=a/e^(bx)sin(x))
    def tendline10(x,a,b):
        return a/np.exp(b*x)*np.sin(np.pi*x/180)

    popt10,cov10=curve_fit(tendline10,df.iloc[:,0],df.iloc[:,1],maxfev=10000)
    data_x=df.iloc[:,0]
    data_y10=popt10[0]/np.exp(popt10[1]*data_x)*np.sin(np.pi*data_x/180)

    """plt.title("range error model")
    plt.xlabel("parameter")
    plt.ylabel("pseudo-range residual RMS")
    plt.grid(True)
    plt.scatter(df.iloc[:,0],df.iloc[:,1])
    plt.plot(data_x,data_y10,color="red")"""

    display(Math(r"y=\frac{a}{e^{bx}sin(x)}"))
    print(popt10)
    print(r2_score(df.iloc[:,1],data_y10s))
    
    return(data_x,data_y,data_y1,data_y2,data_y3,data_y4,data_y5,data_y6,data_y7,data_y8,data_y9,data_y10)
